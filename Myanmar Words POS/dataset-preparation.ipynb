# %%
from datasets import Dataset
from pathlib import Path

# %% [markdown]
# # Read the data from text files

# %%
# Download the text-files folder from https://github.com/myanmartools/myanmar-words
base_path = "./text-files"
base = Path(base_path)

data = {"POS Tag (English)": [], "POS Tag (Myanmar)": [], "Alphabet": [], "Word": []}
pos_mapping = {
    "နာမ်များ": "Noun",
    "နာမ်စားများ": "Pronoun",
    "ကြိယာများ": "Verb",
    "နာမဝိသေသနများ": "Adjective",
    "ကြိယာဝိသေသနများ": "Adverb",
    "ဝိဘတ်များ": "Postposition",
    "သမ္ဗန္ဓများ": "Conjunction",
    "ပစ္စည်းများ": "Particle",
    "အာမေဍိတ်များ": "Interjection"
}

# Sort folders first
for folder in sorted(base.iterdir()):
    if folder.is_dir():
        # Sort files within each folder
        for file in sorted(folder.glob('*.txt')):
            content = file.read_text(encoding='utf-8').strip().split("\n")
            folder_name = folder.name
            file_name = file.name.split("-")[0]

            data["POS Tag (Myanmar)"].extend([folder_name.replace("များ", "")] * len(content))
            data["POS Tag (English)"].extend([pos_mapping[folder_name]] * len(content))
            data["Word"].extend(content)
            data["Alphabet"].extend([file_name] * len(content))

# %% [markdown]
# # Read into HuggingFace Dataset and Push

# %%
dataset = Dataset.from_dict(data)
dataset
# Out:
# Dataset({
#     features: ['POS Tag (English)', 'POS Tag (Myanmar)', 'Alphabet', 'Word'],
#     num_rows: 27894
# })

# %%
dataset.push_to_hub("chuuhtetnaing/myanmar-words-pos-dataset", private=True, token="")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ? shards/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/datasets/chuuhtetnaing/myanmar-words-pos-dataset/commit/cf46da589612e0e9af80ed6c92a9f4f54a5e8243', commit_message='Upload dataset', commit_description='', oid='cf46da589612e0e9af80ed6c92a9f4f54a5e8243', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/chuuhtetnaing/myanmar-words-pos-dataset', endpoint='https://huggingface.co', repo_type='dataset', repo_id='chuuhtetnaing/myanmar-words-pos-dataset'), pr_revision=None, pr_num=None)
